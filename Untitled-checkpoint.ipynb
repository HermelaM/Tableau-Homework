# %%
import csv
import pandas as pd 
import numpy as np
import datetime as dt

# %%
# import CSV file 
May2019 = pd.read_csv("201904-citibike-tripdata.csv")
May2020 = pd.read_csv('202004-citibike-tripdata.csv')

# %%
May2019
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                  88  2019-04-01 00:00:14.7410  2019-04-01 00:01:42.8900
# 1                 443  2019-04-01 00:00:20.8270  2019-04-01 00:07:44.2920
# 2                 662  2019-04-01 00:00:30.9960  2019-04-01 00:11:33.2610
# 3                  86  2019-04-01 00:00:30.9110  2019-04-01 00:01:56.9600
# 4                 136  2019-04-01 00:00:32.5930  2019-04-01 00:02:49.3910
# ...               ...                       ...                       ...
# 1766089           516  2019-04-30 23:59:33.7520  2019-05-01 00:08:10.1700
# 1766090           435  2019-04-30 23:59:35.0850  2019-05-01 00:06:50.4610
# 1766091           564  2019-04-30 23:59:40.1050  2019-05-01 00:09:04.3660
# 1766092           675  2019-04-30 23:59:43.2650  2019-05-01 00:10:58.6670
# 1766093          1764  2019-04-30 23:59:50.8000  2019-05-01 00:29:15.0230
#
#          start station id          start station name  start station latitude  \
# ...

# %%
combined_df = May2019.append([May2020], ignore_index=True)
combined_df['gender'].replace({0:'Unknown',1:'Male', 2: 'Female'},inplace=True)
combined_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0            88  2019-04-01 00:00:14.7410  2019-04-01 00:01:42.8900
# 1           443  2019-04-01 00:00:20.8270  2019-04-01 00:07:44.2920
# 2           662  2019-04-01 00:00:30.9960  2019-04-01 00:11:33.2610
# 3            86  2019-04-01 00:00:30.9110  2019-04-01 00:01:56.9600
# 4           136  2019-04-01 00:00:32.5930  2019-04-01 00:02:49.3910
#
#    start station id      start station name  start station latitude  \
# 0              2006  Central Park S & 6 Ave               40.765909
# 1               254         W 11 St & 6 Ave               40.735324
# 2              3244  University Pl & E 8 St               40.731437
# 3               526         E 33 St & 5 Ave               40.747659
# 4               461         E 20 St & 2 Ave               40.735877
#
#    start station longitude  end station id         end station name  \
# 0               -73.976342            2006   Central Park S & 6 Ave
# ...

# %%
combined_df['starttime'] = pd.to_datetime(combined_df["starttime"])
combined_df ['stoptime'] = pd.to_datetime(combined_df["stoptime"])
combined_df.head()
# Out:
#    tripduration               starttime                stoptime  \
# 0            88 2019-04-01 00:00:14.741 2019-04-01 00:01:42.890
# 1           443 2019-04-01 00:00:20.827 2019-04-01 00:07:44.292
# 2           662 2019-04-01 00:00:30.996 2019-04-01 00:11:33.261
# 3            86 2019-04-01 00:00:30.911 2019-04-01 00:01:56.960
# 4           136 2019-04-01 00:00:32.593 2019-04-01 00:02:49.391
#
#    start station id      start station name  start station latitude  \
# 0              2006  Central Park S & 6 Ave               40.765909
# 1               254         W 11 St & 6 Ave               40.735324
# 2              3244  University Pl & E 8 St               40.731437
# 3               526         E 33 St & 5 Ave               40.747659
# 4               461         E 20 St & 2 Ave               40.735877
#
#    start station longitude  end station id         end station name  \
# 0               -73.976342            2006   Central Park S & 6 Ave
# ...

# %%
combined_df.dtypes
# Out:
# tripduration                        int64
# starttime                  datetime64[ns]
# stoptime                   datetime64[ns]
# start station id                    int64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                      int64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                             object
# dtype: object

# %%
clean_data = pd.combined_df, columns=["gender", "split"]
clean_data = combined_df['gender'].replace({0:'Unknown',1:'Male', 2: 'Female'},inplace=True)
clean_data

# %%
combined_df.to_csv("clean-citibike-tripdata.csv", index=False, header=True)
